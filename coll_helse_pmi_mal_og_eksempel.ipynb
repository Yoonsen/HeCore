# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
ref = pd.read_json('Avisdata/avis_agg.json')

# %%
ref.loc[['.',',','og', 'i']]
# Out:
#         1950      1960      1970      1980      1990
# .   0.067800  0.063615  0.062691  0.063976  0.067793
# ,   0.042249  0.041280  0.036016  0.037534  0.036030
# og  0.020793  0.021255  0.018819  0.018702  0.016739
# i   0.024536  0.024625  0.024151  0.022346  0.020813

# %%
keyword = 'helse'

# %%
filename = 'collocation_' + keyword + ".csv"

# %%
try:
    agg = pd.read_csv('agg_' + filename, index_col = 0)
except:
    print('no gikk galt')

# %%
agg.head(20)
# Out:
#               1950      1960      1970          1980          1990
# !         0.002028  0.001569  0.001349  1.436626e-03  1.475785e-03
# "         0.000928  0.000959  0.000857  6.156971e-04  8.981498e-04
# #         0.000088  0.000397  0.000093  6.683976e-05  9.863799e-05
# $         0.000035  0.000107  0.000073  2.870682e-05  2.270803e-05
# %         0.000185  0.000261  0.000192  2.138016e-04  3.522110e-04
# &         0.000438  0.000577  0.000555  3.217735e-04  4.965015e-04
# '         0.002803  0.002351  0.001902  1.315372e-03  1.435573e-03
# (         0.001789  0.002104  0.002907  2.916527e-03  4.085316e-03
# )         0.001774  0.001868  0.002714  2.789703e-03  3.941498e-03
# *         0.002074  0.001554  0.001274  9.850296e-04  1.285605e-03
# +         0.000026  0.000035  0.000024  3.770448e-05  9.958416e-05
# ,         0.042128  0.041050  0.038261  3.911283e-02  4.451838e-02
# -         0.003251  0.003635  0.005208  6.186106e-03  1.018999e-02
# .         0.059708  0.060228  0.059670  5.908421e-02  5.717999e-02
# ...       0.000075  0.000123  0.000120  1.945209e-04  2.161993e-04
# ....      0.000030  0.000055  0.000020  3.127758e-05  2.081569e-05
# .....     0.000005  0.000006  0.000003  1.285380e-06  4.967381e-06
# ......    0.000005  0.000004  0.000006  1.285380e-06  2.365419e-07
# .......   0.000000  0.000001  0.000000  4.284600e-07  2.128878e-06
# ........  0.000000  0.000003  0.000000  0.000000e+00  0.000000e+00

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=2.2, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(i)))
# Out:
# <span style='font-size:1.1em'>helse, idrett, Kosthold, sosiale, kultur, skole, Helse, vitalitet, livsstil, tobakk, aktivitet, næringsliv, fysisk, samfunn, utvikling, trygghet, hygiene, omsorg, ernæring, sunnhet, liv, miljø, skjønnhet, arbeidsevne, næring, helse-, trening, velferd, livskvalitet, natur, aldring, velvære, barnehager, kropp, glede, sport, fritid, vekst, lykke, eldreomsorg, levekår, kosthold, sosial, trivsel, mat, samferdsel</span>
# <span style='font-size:1.1em'>trygghet, Helse, helse, sunnhet, miljø, velferd, livskvalitet, aldring, trivsel, velvære</span>
# <span style='font-size:1.1em'>helse, ernæring, kosthold, trening, aktivitet, mat</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### kultur-miljø
# <span style='font-size:1.1em'>kultur, miljø, aktivitet, idrett, næring, oppvekst, fysisk, samferdsel, landbruk, energi, teknikk, natur, friluftsliv, fritid, lek, leik, arbeid, klima, kunst, folkehelse, næringsliv, politikk, samfunn, utvikling, sikkerhet, engasjement, medier, sport, kroppsøving, religion, historie</span>
# ### skole-butikk
# <span style='font-size:1.1em'>skole, butikk, daghjem, barnehave, barnehage</span>
# ### sosialetaten-helse-
# <span style='font-size:1.1em'>sosialetaten, helse-, sosialsjef, sosialstyret, sosialsektoren, Helse-, sosialfag, sosialfaglig, heise-, sosialsaker, se-, trygde-, lelse-, skole-, omsorgs-, helsesjef, kultur-, helserådet, politiet, formannskapet, Heise-</span>
# ### sosiale-faglige
# <span style='font-size:1.1em'>sosiale, faglige, økonomiske, medisinske, politiske, kulturelle, psykiske, menneskelige, psykologiske, humanitære, helsemessige, okonomiske</span>
# ### helse-eldreomsorg
# <span style='font-size:1.1em'>helse, eldreomsorg, kosthold, sosial, ernæring, Kosthold, aldring, telekom, trening, livsstil, hygiene, barnehager, helsevesen, barnevern, kreft, okonomisk, mosjon, skoler, psykiatri, internett, økonomisk, helsetjenester, kulturell, helsefag, it, helsestell, politisk</span>
# ### kropp-liv
# <span style='font-size:1.1em'>kropp, liv, ånd, sjel, død, utseende, lære, hode, hjerne, seksualitet, stemme, sinn, ansikt, dod, sex</span>
# ### velferd-trivsel
# <span style='font-size:1.1em'>velferd, trivsel, livskvalitet, velvære, sunnhet, Helse, trygghet, sysselsetting, glede, sykdom, vitalitet, livsglede, skjønnhet, vekst, trim, levekår, arbeidsplasser, velstand, sundhet, demokrati, verdiskaping, luksus, styrke, arbeidsevne, menneskeverd, læring, fremgang, lykke, komfort, hygge, mestring</span>
# ### omsorg-kjærlighet
# <span style='font-size:1.1em'>omsorg, kjærlighet, pleie, god, pleie-, hjelp, godhet, omtanke, varme, rehabilitering</span>
# ### mat-Mat
# <span style='font-size:1.1em'>mat, Mat, kaffe, kaffi, vin, kopp, husly, overnatting, medisiner, vann, tobakk, drikke, klær</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %% [markdown]
# # Skip hvis filen allerede er lastet inn

# %%
from time import time

collocations = dict()
step = 1

for i in range(1950, 2000):
    print(i)
    t0 = time()
    try:
        collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)
    print((time() - t0)/60, "minutter")

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
agg = group_frames(colls)

# %%
agg.to_csv('agg_' + filename)

# %%
nb.normalize_corpus_dataframe(agg)

# %%
ref = group_frames(reference)
nb.normalize_corpus_dataframe(ref)

# %% [markdown]
# ## slutt på skip

# %% [markdown]
# # Opptelling

# %% [markdown]
# # Sammenligner med en referanse

# %%
ref.sort_values(by=ref.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row1_col0 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row1_col1 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row1_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row1_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row1_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row2_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row2_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row2_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row2_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row2_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row3_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row3_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row3_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row3_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row3_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row4_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row4_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row4_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row4_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row4_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row5_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row5_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row5_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row6_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row6_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row6_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row7_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row7_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row7_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row8_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row8_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row9_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row9_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col0" class="data row0 col0" >0.0678003</td>
#                         <td id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col1" class="data row0 col1" >0.0636145</td>
#                         <td id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col2" class="data row0 col2" >0.0626906</td>
#                         <td id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col3" class="data row0 col3" >0.0639755</td>
#                         <td id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2row0_col4" class="data row0 col4" >0.0677927</td>
#             </tr>
#             <tr>
#                         <th id="T_3657b7fa_889f_11ea_b5b9_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row1_col0 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row1_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row1_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row1_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row1_col4 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row2_col0 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row2_col1 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row2_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row2_col3 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row2_col4 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row3_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row3_col1 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row3_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row3_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row3_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row4_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row4_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row4_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row4_col3 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row4_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row5_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row5_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row5_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row5_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row5_col4 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row6_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row6_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row6_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row6_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row7_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row7_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row7_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row7_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row7_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row8_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row8_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row9_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_36643946_889f_11ea_9dc5_000acd2bfab2row9_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }</style><table id="T_36643946_889f_11ea_9dc5_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36643946_889f_11ea_9dc5_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col0" class="data row0 col0" >0.0597081</td>
#                         <td id="T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col1" class="data row0 col1" >0.0602275</td>
#                         <td id="T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col2" class="data row0 col2" >0.0596702</td>
#                         <td id="T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col3" class="data row0 col3" >0.0590842</td>
#                         <td id="T_36643946_889f_11ea_9dc5_000acd2bfab2row0_col4" class="data row0 col4" >0.05718</td>
#             </tr>
#             <tr>
#                         <th id="T_36643946_889f_11ea_9dc5_000acd2bfab2level0_row1" class="row_heading level0 row1" >og</th>

# %%
ref.columns =  [str(c) for c in ref.columns]

# %%
ref['1950']
# Out:
# !       2.217887e-03
# "       1.693990e-03
# #       1.298063e-04
# $       8.286360e-05
# %       3.758124e-04
#             ...
# ﾫGﾫﾫ    0.000000e+00
# ﾻ       0.000000e+00
# ￥       0.000000e+00
# ￸       0.000000e+00
# �       1.096000e-07
# Name: 1950, Length: 8190907, dtype: float64

# %%
tempref = pd.concat([agg['1950'].head(50),ref['1950'].head(50)], axis=1)

# %%
tempref.head(20)
# Out:
#               1950      1950
# !         0.002028  0.002218
# "         0.000928  0.001694
# #         0.000088  0.000130
# $         0.000035  0.000083
# %         0.000185  0.000376
# &         0.000438  0.000780
# '         0.002803  0.004651
# (         0.001789  0.003038
# )         0.001774  0.003711
# *         0.002074  0.003373
# +         0.000026  0.000136
# ,         0.042128  0.042249
# -         0.003251  0.005315
# .         0.059708  0.067800
# ...       0.000075  0.000154
# ....      0.000030  0.000105
# .....     0.000005  0.000013
# ......    0.000005  0.000014
# .......   0.000000  0.000006
# ........  0.000000  0.000005

# %%
pmi = pd.DataFrame()
exp = 1.1
for i in agg:
    pmi[i] = agg[i]**exp/(agg[i] + ref[i])

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row0_col4 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row1_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row1_col1 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row1_col2 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row1_col3 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row1_col4 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row2_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row2_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row2_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row2_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row3_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row3_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row3_col2 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row3_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row3_col4 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row4_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row4_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row4_col2 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row4_col3 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row4_col4 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row5_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row5_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row5_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row5_col3 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row5_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row6_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row6_col2 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row7_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row7_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row7_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row7_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row7_col4 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row8_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row8_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row8_col2 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row8_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row8_col4 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row9_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row9_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row9_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row9_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row9_col4 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row10_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row10_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row10_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row10_col4 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row11_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row11_col1 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row11_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row11_col3 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_5b079dec_88a2_11ea_90f6_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row0_col4 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row1_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row1_col1 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row1_col2 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row1_col3 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row1_col4 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row2_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row2_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row2_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row2_col4 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row3_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row3_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row3_col2 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row3_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row3_col4 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row4_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row4_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row4_col2 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row4_col3 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row4_col4 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row5_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row5_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row5_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row5_col3 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row5_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row6_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row6_col2 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row7_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row7_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row7_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row7_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row7_col4 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row8_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row8_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row8_col2 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row8_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row8_col4 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row9_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row9_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row9_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row9_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row9_col4 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row10_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row10_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row10_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row10_col4 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row11_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row11_col1 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row11_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row11_col3 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_c4e6e642_88a2_11ea_b004_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(70).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row0_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row0_col2 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row0_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row1_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row1_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row1_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row2_col0 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row2_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row2_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row3_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row3_col2 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row3_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row4_col0 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row4_col2 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row4_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row5_col0 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row5_col2 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row5_col3 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row6_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row6_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row6_col3 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row7_col1 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row7_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row7_col3 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row8_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row8_col2 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row8_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row9_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row9_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row9_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row10_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row10_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row10_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row11_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row11_col2 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row11_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_c5abc69e_88a2_11ea_b6b7_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c65708ca_88a2_11ea_8361_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row0_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row0_col2 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row0_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row1_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row1_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row1_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row2_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row2_col2 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row2_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row3_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row3_col2 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row3_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row4_col1 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row4_col2 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row4_col3 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row5_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row5_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row5_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row6_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row6_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row6_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row7_col1 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row7_col2 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row7_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row8_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row8_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row8_col3 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row9_col1 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row9_col2 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row9_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row10_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row10_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row10_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row11_col1 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row11_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row11_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_c65708ca_88a2_11ea_8361_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row0_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row0_col2 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row0_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row1_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row1_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row1_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row2_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row2_col2 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row2_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row3_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row3_col2 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row3_col3 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row4_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row4_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row4_col4 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row5_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row5_col2 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row5_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row6_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row6_col3 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row6_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row7_col1 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row7_col3 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row7_col4 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row8_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row8_col2 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row8_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row9_col1 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row9_col2 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row9_col3 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row10_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row10_col3 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row10_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row11_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row11_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row11_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_c6f2e3d4_88a2_11ea_8c57_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row0_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row0_col3 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row0_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row1_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row1_col2 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row1_col3 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row2_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row2_col2 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row2_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row3_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row3_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row3_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row4_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row4_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row4_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row5_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row5_col2 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row5_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row6_col1 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row6_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row6_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row7_col1 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row7_col2 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row7_col3 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row8_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row8_col2 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row8_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row9_col1 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row9_col2 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row9_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row10_col1 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row10_col2 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row10_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row11_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row11_col2 {
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row11_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_c78e49e2_88a2_11ea_9d15_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(80).fillna(0).index
# Out:
# Index(['god', 'liv', 'opplysning', 'forberedt', 'helseattest', 'fremlegge',
#        'Søknad', 'attest', 'og', 'sviktende', 'dårlig', 'God', 'Søkere',
#        'trivsel', 'humør', 'sin', 'gi', 'vandel', 'må', 'alder', 'vitnemål',
#        'dråpe', 'sinnets', 'Alder', 'målformer', 'rettkjende', 'velferd',
#        'barnas', 'kosthold', 'fysiske', 'avskrifter', 'attestar', 'psykiske',
#        'sunnhet', 'Lovfestet', 'mentale', 'legeattest', 'legge', 'hatt',
#        'pensjonsordning', 'utdanning', 'attestavskrifter', 'fare', 'behersker',
#        'hørsel', 'fysisk', 'skolestyre', 'Sokere', 'svekket', 'bevare',
#        'framlegge', 'folks', 'attester', 'sendes', 'innan', 'kreves', 'Soknad',
#        'eldres', 'offisielle', 'tilfredsstillende', 'helse', 'Attest', 'melk',
#        'ugift', 'anmodning', 'utskrevne', 'kropp', 'grunn', 'Søknader',
#        'humor', 'fysikk', 'menneskers', 'leggja', 'skulestyre', 'for',
#        'Sinnets', 'være', 'lege', 'realskole', 'fylt'],
#       dtype='object')

# %%
agg.loc[pmi.sort_values(by=pmi.columns[4], ascending=False).head(50).fillna(0).index].style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row0_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row0_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row1_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row1_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row1_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row2_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row2_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row2_col3 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row3_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row3_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row3_col4 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row4_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row4_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row5_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row5_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row5_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row6_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row6_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row6_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row7_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row7_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row7_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row7_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row8_col0 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row8_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row8_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row9_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row9_col2 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row9_col3 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row10_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row10_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row10_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row11_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row11_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row11_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_c976ca98_88a2_11ea_b5f5_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
ordliste = 'liv kropp hygiene ernæring idrett arbeidsmiljø livskvalitet risiko omsorg velvære utdanning tjenester og sosial fysisk psykisk syk sykdom sikkerhet'.split()
ord_art = pmi.loc[ordliste]

# %%
ordliste
# Out:
# ['liv',
#  'kropp',
#  'hygiene',
#  'ernæring',
#  'idrett',
#  'arbeidsmiljø',
#  'livskvalitet',
#  'risiko',
#  'omsorg',
#  'velvære',
#  'utdanning',
#  'tjenester',
#  'og',
#  'sosial',
#  'fysisk',
#  'psykisk',
#  'syk',
#  'sykdom',
#  'sikkerhet']

# %%
pmil = (agg.loc[ordliste]/ref.loc[ordliste]).apply(round)

# %%
pmil['translation'] = ['life',
 'body',
 'hygiene',
 'nutrition',
 'sport',
 'work environment',
 'quality of life',
 'risk',
 'caring',
 'wellness',
 'education',
 'services',
 'and',
 'social',
 'physical',
 'psychic',
 'sick',
 'disease',
 'safety']

# %%
pmil.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row0_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row0_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row0_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row1_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row1_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row1_col3 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row2_col2 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row2_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row2_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row3_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row3_col2 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row3_col4 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row4_col0 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row4_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row4_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row5_col1 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row5_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row5_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row6_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row6_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row6_col4 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row7_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row7_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row7_col4 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row8_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row8_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row8_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row9_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row9_col2 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row9_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row10_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row10_col3 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row10_col4 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row11_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd775c7a_88a2_11ea_beff_000acd2bfab2row11_col4 {
#             background-color:  #045e93;
#             color:  #f

# %%
ordliste2 = 'liv kropp miljø risiko omsorg sosial sikkerhet'.split()

# %%
pmil2 = (agg.loc[ordliste2]/ref.loc[ordliste2]).apply(round)

# %%
pmil2
# Out:
#            1950  1960  1970  1980   1990
# liv        24.0  29.0  33.0  27.0   23.0
# kropp      38.0  62.0  23.0  86.0   91.0
# miljø       2.0   3.0  11.0  21.0   57.0
# risiko      6.0   9.0  16.0  12.0    9.0
# omsorg      9.0   5.0  12.0  22.0   64.0
# sosial      6.0   4.0  18.0  86.0  154.0
# sikkerhet   7.0   7.0  10.0  17.0   50.0

# %%
pmil2['translation'] = ['life',
 'body',
 'environment',
 'risk',
 'caring',
 'social',
 'safety']

# %%
pmil2.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col1 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col3 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col3 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col4 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row4_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row4_col2 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row4_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row5_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row5_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row5_col3 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row6_col2 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row6_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_37003ba4_8a0f_11ea_8048_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>        <th class="col_heading level0 col5" >translation</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2level0_row0" class="row_heading level0 row0" >liv</th>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col0" class="data row0 col0" >24</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col1" class="data row0 col1" >29</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col2" class="data row0 col2" >33</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col3" class="data row0 col3" >27</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col4" class="data row0 col4" >23</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row0_col5" class="data row0 col5" >life</td>
#             </tr>
#             <tr>
#                         <th id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2level0_row1" class="row_heading level0 row1" >kropp</th>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col0" class="data row1 col0" >38</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col1" class="data row1 col1" >62</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col2" class="data row1 col2" >23</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col3" class="data row1 col3" >86</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col4" class="data row1 col4" >91</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row1_col5" class="data row1 col5" >body</td>
#             </tr>
#             <tr>
#                         <th id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2level0_row2" class="row_heading level0 row2" >miljø</th>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col2" class="data row2 col2" >11</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col3" class="data row2 col3" >21</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col4" class="data row2 col4" >57</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row2_col5" class="data row2 col5" >environment</td>
#             </tr>
#             <tr>
#                         <th id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2level0_row3" class="row_heading level0 row3" >risiko</th>
#                         <td id="T_37003ba4_8a0f_11ea_8048_000acd2bfab2row3_col0" class="data row3 col0" >6</td>
#                         <td id="T_37003ba4_8a0f_11ea_8048_0

# %%
words = : “environment”, “social”, “life”, “body”, “security”, “risk”, and “care”

# %%
from pandas.plotting import table

# %%
agg.loc[ordliste].style.bar(axis=1)
# Out:
# <style  type="text/css" >
#     #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 66.2%, transparent 66.2%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.9%, transparent 6.9%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.6%, transparent 17.6%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 63.6%, transparent 63.6%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.7%, transparent 40.7%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.2%, transparent 49.2%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row2_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row3_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.7%, transparent 23.7%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.5%, transparent 96.5%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.8%, transparent 78.8%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row4_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.8%, transparent 73.8%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 7.7%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.3%, transparent 46.3%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.3%, transparent 98.3%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row6_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row6_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.1%, transparent 51.1%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row7_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.6%, transparent 36.6%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.6%, transparent 58.6%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row8_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }    #T_cd86005a_88a2_11ea_ba18_000acd2bfab2row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_cd86005a_88a2_11ea_ba18_000

# %%
pmi.to_csv(filename)

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
