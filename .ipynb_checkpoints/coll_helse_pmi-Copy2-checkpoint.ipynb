# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
reference = pd.read_json('avis_agg_sample_20.json')

# %%
keyword = 'helse'

# %%
filename = 'collocation_' + keyword + ".csv"

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=0.8, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ' ,'.join(i)))
# Out:
# <span style='font-size:1.1em'>livskvalitet ,hygiene ,sunnhet ,idrett ,vekst ,mat ,trening ,trygghet ,liv ,sosiale ,sport ,velvære ,fritid ,levekår ,kultur ,samfunn ,næring ,fysisk ,skjønnhet ,aldring ,tobakk ,eldreomsorg ,sosial ,natur ,kosthold ,aktivitet ,livsstil ,ernæring ,arbeidsevne ,Helse ,lykke ,glede ,omsorg ,kropp ,næringsliv ,helse- ,barnehager ,samferdsel ,velferd ,helse ,miljø ,skole ,trivsel ,utvikling ,Kosthold ,vitalitet</span>
# <span style='font-size:1.1em'>livskvalitet ,helse ,sunnhet ,miljø ,Helse ,trivsel ,trygghet ,aldring ,velferd ,velvære</span>
# <span style='font-size:1.1em'>helse ,ernæring ,mat ,trening ,kosthold ,aktivitet</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### kultur-miljø
# <span style='font-size:1.1em'>kultur, miljø, aktivitet, idrett, næring, oppvekst, fysisk, samferdsel, teknikk, landbruk, lek, fritid, natur, energi, friluftsliv, engasjement, sikkerhet, sport, religion, leik, samfunn, næringsliv, medier, folkehelse, klima, politikk, kroppsøving, kunst, utvikling, arbeid, historie</span>
# ### skole-butikk
# <span style='font-size:1.1em'>skole, butikk, barnehave, daghjem, barnehage</span>
# ### sosialetaten-sosialsjef
# <span style='font-size:1.1em'>sosialetaten, sosialsjef, helse-, sosialstyret, sosialsektoren, sosialfag, Helse-, sosialsaker, sosialfaglig, heise-, se-, lelse-, trygde-, kultur-, omsorgs-, Heise-, helsesjef, skole-, politiet, formannskapet, helserådet</span>
# ### sosiale-kulturelle
# <span style='font-size:1.1em'>sosiale, kulturelle, helsemessige, menneskelige, politiske, økonomiske, okonomiske, psykologiske, medisinske, psykiske, humanitære, faglige</span>
# ### helse-eldreomsorg
# <span style='font-size:1.1em'>helse, eldreomsorg, kosthold, sosial, ernæring, aldring, Kosthold, telekom, trening, hygiene, livsstil, barnehager, barnevern, helsevesen, skoler, okonomisk, politisk, it, kreft, internett, helsefag, kulturell, helsetjenester, økonomisk, mosjon, psykiatri, helsestell</span>
# ### kropp-liv
# <span style='font-size:1.1em'>kropp, liv, ånd, sjel, død, utseende, hjerne, lære, stemme, sex, ansikt, dod, seksualitet, hode, sinn</span>
# ### velferd-trivsel
# <span style='font-size:1.1em'>velferd, trivsel, livskvalitet, velvære, sunnhet, Helse, trygghet, sysselsetting, glede, vekst, livsglede, levekår, skjønnhet, sykdom, trim, arbeidsplasser, vitalitet, verdiskaping, mestring, menneskeverd, læring, demokrati, styrke, luksus, arbeidsevne, lykke, velstand, hygge, sundhet, komfort, fremgang</span>
# ### omsorg-rehabilitering
# <span style='font-size:1.1em'>omsorg, rehabilitering, god, pleie, pleie-, varme, godhet, omtanke, kjærlighet, hjelp</span>
# ### mat-Mat
# <span style='font-size:1.1em'>mat, Mat, vin, kaffe, kopp, kaffi, medisiner, overnatting, drikke, tobakk, husly, klær, vann</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
from time import time

collocations = dict()
step = 1

for i in range(1950, 2000):
    print(i)
    t0 = time()
    try:
        collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)
    print((time() - t0)/60, "minutter")
# Out:
# 1950
# 0.02107075850168864 minutter
# 1951
# 0.021313480536142983 minutter
# 1952
# 0.023323102792104086 minutter
# 1953
# 0.023150873184204102 minutter
# 1954
# 0.025521206855773925 minutter
# 1955
# 0.027748556931813557 minutter
# 1956
# 0.028574534257253013 minutter
# 1957
# 0.025604267915089924 minutter
# 1958
# 0.02651454210281372 minutter
# 1959
# 0.02790273427963257 minutter
# 1960
# 0.027790351708730062 minutter
# 1961
# 0.03122869332631429 minutter
# 1962
# 0.032576453685760495 minutter
# 1963
# 0.033711727460225424 minutter
# 1964
# 0.030823326110839842 minutter
# 1965
# 0.028899804751078288 minutter
# 1966
# 0.02877427339553833 minutter
# 1967
# 0.027537246545155842 minutter
# 1968
# 0.029928608735402425 minutter
# 1969
# 0.03031348784764608 minutter
# 1970
# 0.0294365127881368 minutter
# 1971
# 0.027770296732584635 minutter
# 1972
# 0.02978661060333252 minutter
# 1973
# 0.02985774278640747 minutter
# 1974
# 0.030986122290293374 minutter
# 1975
# 0.03033469518025716 minutter
# 1976
# 0.03173131942749023 minutter
# 1977
# 0.02980746825536092 minutter
# 1978
# 0.030116713047027587 minutter
# 1979
# 0.032606263955434166 minutter
# 1980
# 0.03146676222483317 minutter
# 1981
# 0.03191514809926351 minutter
# 1982
# 0.03209837277730306 minutter
# 1983
# 0.03638145923614502 minutter
# 1984
# 0.034784579277038576 minutter
# 1985
# 0.039599565664927165 minutter
# 1986
# 0.04072778622309367 minutter
# 1987
# 0.0394591490427653 minutter
# 1988
# 0.03975623846054077 minutter
# 1989
# 0.05555322964986165 minutter
# 1990
# 0.057094025611877444 minutter
# 1991
# 0.053251500924428305 minutter
# 1992
# 0.05348909298578898 minutter
# 1993
# 0.05332415501276652 minutter
# 1994
# 0.05678841272989909 minutter
# 1995
# 0.056029248237609866 minutter
# 1996
# 0.055477575461069746 minutter
# 1997
# 0.06018661260604859 minutter
# 1998
# 0.056539897123972574 minutter
# 1999
# 0.053419625759124754 minutter

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
agg.to_csv('agg_' + filename)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %%
ref = group_frames(reference)
nb.normalize_corpus_dataframe(ref)
# Out:
# True

# %% [markdown]
# # Opptelling

# %% [markdown]
# # Sammenligner med en referanse

# %%
ref.sort_values(by=ref.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row1_col0 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row1_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row1_col2 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row1_col3 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row1_col4 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row2_col0 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row2_col1 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row2_col2 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row2_col3 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row2_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row3_col0 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row3_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row3_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row3_col3 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row3_col4 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row4_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row4_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row4_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row4_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row4_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row5_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row5_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row5_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row5_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row6_col2 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row6_col3 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row6_col4 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row7_col0 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row7_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row7_col2 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row7_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row7_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row8_col0 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row8_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row8_col2 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row9_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row9_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row9_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }</style><table id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col0" class="data row0 col0" >0.0663397</td>
#                         <td id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col1" class="data row0 col1" >0.0632207</td>
#                         <td id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col2" class="data row0 col2" >0.0621348</td>
#                         <td id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col3" class="data row0 col3" >0.0647454</td>
#                         <td id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2row0_col4" class="data row0 col4" >0.067428</td>
#             </tr>
#             <tr>
#                         <th id="T_d5fe5a74_5e72_11ea_8627_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row1_col0 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row1_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row1_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row1_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row1_col4 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row2_col0 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row2_col1 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row2_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row2_col3 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row2_col4 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row3_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row3_col1 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row3_col2 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row3_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row3_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row4_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row4_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row4_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row4_col3 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row4_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row5_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row5_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row5_col2 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row5_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row5_col4 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row6_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row6_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row6_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row6_col4 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row7_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row7_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row7_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row7_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row7_col4 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row8_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row8_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row9_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d6100b12_5e72_11ea_b180_000acd2bfab2row9_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }</style><table id="T_d6100b12_5e72_11ea_b180_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6100b12_5e72_11ea_b180_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col0" class="data row0 col0" >0.0597081</td>
#                         <td id="T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col1" class="data row0 col1" >0.0602275</td>
#                         <td id="T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col2" class="data row0 col2" >0.0596702</td>
#                         <td id="T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col3" class="data row0 col3" >0.0590842</td>
#                         <td id="T_d6100b12_5e72_11ea_b180_000acd2bfab2row0_col4" class="data row0 col4" >0.05718</td>
#             </tr>
#             <tr>
#                         <th id="T_d6100b12_5e72_11ea_b180_000acd2bfab2level0_row1" class="row_heading level0 row1" >og</th>

# %%
pmi = pd.DataFrame()
exp = 1.1
for i in agg:
    pmi[i] = agg[i]**exp/(pd.concat([agg[i], ref[i]],axis=1).sum(axis=1))

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row0_col4 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row1_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row1_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row1_col2 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row1_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row1_col4 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row2_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row2_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row2_col3 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row2_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row3_col0 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row3_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row3_col2 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row3_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row3_col4 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row4_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row4_col2 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row4_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row4_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row5_col0 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row5_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row5_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row6_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row6_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row6_col2 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row6_col3 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row6_col4 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row7_col0 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row7_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row7_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row7_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row7_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row8_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row8_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row8_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row8_col3 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row8_col4 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row9_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row9_col1 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row9_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row9_col3 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row9_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row10_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row10_col2 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row10_col3 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row10_col4 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row11_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row11_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row11_col2 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row11_col3 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_1bd5123a_5e73_11ea_906c_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row0_col4 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row1_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row1_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row1_col2 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row1_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row1_col4 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row2_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row2_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row2_col3 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row2_col4 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row3_col0 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row3_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row3_col2 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row3_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row3_col4 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row4_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row4_col2 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row4_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row4_col4 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row5_col0 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row5_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row5_col2 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row6_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row6_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row6_col2 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row6_col3 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row6_col4 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row7_col0 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row7_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row7_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row7_col3 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row7_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row8_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row8_col1 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row8_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row8_col3 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row8_col4 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row9_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row9_col1 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row9_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row9_col3 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row9_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row10_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row10_col2 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row10_col3 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row10_col4 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row11_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row11_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row11_col2 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row11_col3 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_1c0fa148_5e73_11ea_ab78_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(70).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row0_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row0_col2 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row0_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row1_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row1_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row1_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row2_col0 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row2_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row2_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row3_col0 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row3_col2 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row3_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row4_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row4_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row4_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row5_col0 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row5_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row5_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row6_col1 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row6_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row6_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row7_col1 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row7_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row7_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row8_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row8_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row8_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row9_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row9_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row9_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row10_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row10_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row10_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row11_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row11_col2 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row11_col3 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_1c4f8726_5e73_11ea_8ed4_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row0_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row0_col2 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row0_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row1_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row1_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row1_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row2_col1 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row2_col2 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row2_col3 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row3_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row3_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row3_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row4_col1 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row4_col2 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row4_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row5_col1 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row5_col2 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row5_col3 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row6_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row6_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row6_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row7_col1 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row7_col2 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row7_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row8_col1 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row8_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row8_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row9_col1 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row9_col2 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row9_col3 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row10_col1 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row10_col2 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row10_col3 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row11_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row11_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row11_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_1c905742_5e73_11ea_b7b5_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row0_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row0_col2 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row0_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row1_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row1_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row1_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row2_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row2_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row2_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row3_col1 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row3_col2 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row3_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row4_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row4_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row4_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row5_col1 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row5_col2 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row5_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row6_col0 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row6_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row6_col3 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row7_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row7_col3 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row7_col4 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row8_col0 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row8_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row8_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row9_col1 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row9_col2 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row9_col3 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row10_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row10_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row10_col3 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row11_col1 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row11_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row11_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1ccc9426_5e73_11ea_a945_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1d144118_5e73_11ea_b727_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row0_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row0_col2 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row0_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row1_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row1_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row1_col3 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row2_col1 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row2_col2 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row2_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row3_col1 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row3_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row3_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row4_col1 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row4_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row4_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row5_col1 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row5_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row5_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row6_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row6_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row6_col2 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row6_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row7_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row7_col1 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row7_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row7_col3 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row8_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row8_col2 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row8_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row9_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row9_col1 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row9_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row9_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row10_col1 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row10_col2 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row10_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row11_col0 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row11_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row11_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_1d144118_5e73_11ea_b727_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(80).fillna(0).index
# Out:
# Index(['god', 'liv', 'opplysning', 'forberedt', 'helseattest', 'fremlegge',
#        'Søknad', 'attest', 'og', 'dårlig', 'sviktende', 'God', 'trivsel',
#        'Søkere', 'humør', 'vandel', 'sin', 'gi', 'må', 'vitnemål', 'alder',
#        'dråpe', 'sinnets', 'målformer', 'Alder', 'rettkjende', 'velferd',
#        'barnas', 'kosthold', 'attestar', 'fysiske', 'avskrifter', 'legeattest',
#        'sunnhet', 'Lovfestet', 'psykiske', 'mentale', 'legge', 'hatt',
#        'pensjonsordning', 'attestavskrifter', 'utdanning', 'fare', 'behersker',
#        'skolestyre', 'hørsel', 'Sokere', 'fysisk', 'innan', 'svekket',
#        'framlegge', 'Soknad', 'bevare', 'eldres', 'attester', 'kreves',
#        'sendes', 'ugift', 'helse', 'folks', 'offisielle', 'melk', 'Attest',
#        'Søknader', 'utskrevne', 'tilfredsstillende', 'anmodning', 'kropp',
#        'leggja', 'grunn', 'skulestyre', 'menneskers', 'fysikk', 'humor', 'for',
#        'Sinnets', 'være', 'bokmål', 'lege', 'Tollak'],
#       dtype='object')

# %%
agg.loc[pmi.sort_values(by=pmi.columns[4], ascending=False).head(50).fillna(0).index].style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row0_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row0_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row0_col3 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row1_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row1_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row1_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row2_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row2_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row2_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row3_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row3_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row3_col4 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row4_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row4_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row5_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row5_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row5_col3 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row6_col1 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row6_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row6_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row7_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row7_col2 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row7_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row7_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row8_col0 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row8_col2 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row8_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row9_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row9_col2 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row9_col3 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row10_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row10_col1 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row10_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row11_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row11_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row11_col3 {
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }    #T_1d89128c_5e73_11ea_9d85_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %%
ordliste = 'liv kropp hygiene ernæring idrett arbeidsmiljø livskvalitet risiko omsorg velvære utdanning tjenester og sosial fysisk psykisk syk sykdom sikkerhet'.split()
ord_art = pmi.loc[ordliste]

# %%
ordliste
# Out:
# ['liv',
#  'kropp',
#  'hygiene',
#  'ernæring',
#  'idrett',
#  'arbeidsmiljø',
#  'livskvalitet',
#  'risiko',
#  'omsorg',
#  'velvære',
#  'utdanning',
#  'tjenester',
#  'og',
#  'sosial',
#  'fysisk',
#  'psykisk',
#  'syk',
#  'sykdom',
#  'sikkerhet']

# %%
pmil = (agg.loc[ordliste]/ref.loc[ordliste]).apply(round)

# %%
pmil['translation'] = ['life',
 'body',
 'hygiene',
 'nutrition',
 'sport',
 'work environment',
 'quality of life',
 'risk',
 'caring',
 'wellness',
 'education',
 'services',
 'and',
 'social',
 'physical',
 'psychic',
 'sick',
 'disease',
 'safety']

# %%
pmil.fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row0_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row0_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row0_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row1_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row1_col1 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row1_col3 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row2_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row2_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row2_col3 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row3_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row3_col2 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row3_col3 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row4_col0 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row4_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row4_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row5_col2 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row5_col3 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row5_col4 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row6_col3 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row6_col4 {
#             background-color:  #046299;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row7_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row7_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row7_col4 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row8_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row8_col2 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row8_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row9_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row9_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row9_col3 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row10_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row10_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row10_col3 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row10_col4 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row11_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1e19f2b4_5e73_11ea_915f_000acd2bfab2row11_col4 {
#             background-color:  #056ba7;
#             color:  #f

# %%
agg.loc[ordliste].style.bar(axis=1)
# Out:
# <style  type="text/css" >
#     #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 66.2%, transparent 66.2%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.9%, transparent 6.9%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.6%, transparent 17.6%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 63.6%, transparent 63.6%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.7%, transparent 40.7%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.2%, transparent 49.2%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row2_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row3_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.7%, transparent 23.7%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.5%, transparent 96.5%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.8%, transparent 78.8%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row4_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.8%, transparent 73.8%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 7.7%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.3%, transparent 46.3%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.3%, transparent 98.3%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row6_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row6_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.1%, transparent 51.1%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row7_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.6%, transparent 36.6%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.6%, transparent 58.6%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row8_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000acd2bfab2row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.0%, transparent 24.0%);
#         }    #T_1e2059d4_5e73_11ea_a4c0_000

# %%
pmi.to_csv(filename)

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
