# %% [markdown]
# # Kollokasjoner for nøkkelord

# %% [markdown]
# Jeg foreslår disse ordene til stolper - hvis du Helge heller vil ha noen andre, så rop ut. Tanken er jo her å underbygge argumentasjonen som allerede er der i artikkelen om hvordan de to begrepene aggregerer meninger over tid. Lars skal utføre dette (pluss skrive tekst til metodedelen) senere i dag.
#
# Helse:
# - trivsel
# - klima
# - kosthold
# - industri
#
# Sykdom:
# - skade
# - lidelse
# - feilernæring
# - uførhet

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle
import numpy as np

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
nøkkelord = 'sykdom'

# %%
keyword_graph = nb.make_graph(nøkkelord, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=0.8, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(i)))
# Out:
# <span style='font-size:1.1em'>velvære, nod, bryllup, fornedrelse, alderdom, epidemier, arbeidsledighet, smerter, skader, helse, alder, slit, ulemper, undertrykkelse, sorg, nød, uførhet, dødsfall, sykdommer, bortgang, fattigdom, problemer, kultur, Skader, sult, sykdom, kosthold, lidelser, smerte, dod, elendighet, ødeleggelse, død, aldring, underernæring, sygdom, ondskap, savn, begravelse, trivsel, ulykker, feilernæring, plager, übehag, sjukdom, angst, sunnhet, vold, uhell, krig, lidelse, Sykdom, skade, arbeidsløshet, liv, mangelsykdommer</span>
# <span style='font-size:1.1em'>sorg, nød, smerte, elendighet, nod, død, krig, underernæring, lidelse, fattigdom, sult, sykdom</span>
# <span style='font-size:1.1em'>skader, plager, sykdom, smerter</span>
# <span style='font-size:1.1em'>uførhet, sykdom, alderdom, død</span>
# <span style='font-size:1.1em'>nød, nod, elendighet, lidelse, fattigdom, sult, sykdom</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### lidelse-smerte
# <span style='font-size:1.1em'>lidelse, smerte, plager, smerter, sykdommer, sorg, lidelser, savn, übehag, angst, glede, bekymringer, Sorg, lidenskap, fortvilelse, symptomer, sjukdomar, problemer, feber, lengsel, tyngde, stivhet, redsel</span>
# ### død-dod
# <span style='font-size:1.1em'>død, dod, liv, ødeleggelse, be-, gravferd, begra-, fordervelse, undergang, oppstandelse, Kjærlighet, kjærlighet, maktesløs, ondskap, Liv, grav, lemlestelse, begravet</span>
# ### skader-ulykker
# <span style='font-size:1.1em'>skader, ulykker, skade, Skader, ulemper, tap, defekter, uhell, Sykdom, rust, karantener, slitasje, maver, drepe, formsvikt, mangler, branner, katastrofer, ulempe, suspensjoner, hendelser</span>
# ### sykdom-sjukdom
# <span style='font-size:1.1em'>sykdom, sjukdom, bortgang, begravelse, dødsfall, sygdom, bisettelse, bryllup, sykeleie, bort-</span>
# ### sunnhet-helse
# <span style='font-size:1.1em'>sunnhet, helse, trivsel, skjønnhet, miljø, velvære, styrke, aldring, sosial, kultur, kosthold</span>
# ### fattigdom-sult
# <span style='font-size:1.1em'>fattigdom, sult, elendighet, underernæring, nød, nod, arbeidsløshet, fornedrelse, epidemier, undertrykkelse, feilernæring, krig, arbeidsledighet, slit, rikdom, naud, kulde, vold, tørst, kriminalitet, mangelsykdommer</span>
# ### uførhet-alderdom
# <span style='font-size:1.1em'>uførhet, alderdom, alder, sykefravær, adresse, kjønn</span>
# ### ferier-ferie
# <span style='font-size:1.1em'>ferier, ferie, ferieavvikling, fridager, fritid, weekend, høytider, helger, lignende, ellers, reiser, week-end, avkobling, annet, rekreasjon, avspasering, permisjoner, weekender, arbeidstid, sykdomsfravær</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
reference = pd.read_json('../Avisdata/avis_agg.json')

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
keyword = nøkkelord

# %%
barchart(keyword, reference);

# %%
collocations = dict()
step = 1
for i in range(1950, 2000):
    try:
        collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %% [markdown]
# # Opptelling

# %%
reference.sort_values(by=reference.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row1_col0 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row1_col1 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row1_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row1_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row1_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row2_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row2_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row2_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row2_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row2_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row3_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row3_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row3_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row3_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row3_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row4_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row4_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row4_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row4_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row4_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row5_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row5_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row5_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row6_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row6_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row6_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row7_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row7_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row7_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row8_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row8_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row9_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row9_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0df0b8f6_2530_11ea_a560_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col0" class="data row0 col0" >0.0678003</td>
#                         <td id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col1" class="data row0 col1" >0.0636145</td>
#                         <td id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col2" class="data row0 col2" >0.0626906</td>
#                         <td id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col3" class="data row0 col3" >0.0639755</td>
#                         <td id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2row0_col4" class="data row0 col4" >0.0677927</td>
#             </tr>
#             <tr>
#                         <th id="T_0df0b8f6_2530_11ea_a560_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row1_col0 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row1_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row1_col2 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row1_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row1_col4 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row2_col1 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row2_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row2_col3 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row2_col4 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row3_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row3_col1 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row3_col2 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row3_col3 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row3_col4 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row4_col0 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row4_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row4_col2 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row4_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row4_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row5_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row5_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row5_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row5_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row5_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row6_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row6_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row6_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row6_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row6_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row7_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row7_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row7_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row7_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row7_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row8_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row8_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row8_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row8_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col0" class="data row0 col0" >0.0696535</td>
#                         <td id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col1" class="data row0 col1" >0.0664274</td>
#                         <td id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col2" class="data row0 col2" >0.0657622</td>
#                         <td id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col3" class="data row0 col3" >0.0670503</td>
#                         <td id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2row0_col4" class="data row0 col4" >0.0657344</td>
#             </tr>
#             <tr>
#                         <th id="T_0e01a66c_2530_11ea_a2c6_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %% [markdown]
# pmi = pd.DataFrame()
# for i in agg:
#     pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))

# %%
larger = lambda n, agg, col: n*min(agg[col][agg[col] > 0])

# %%
pmi = pd.DataFrame()
for i in agg:
    cutoff = larger(12, agg, i)
    pmi[i] = agg[i][agg[i] >= cutoff]/reference[i]
pmi = pmi.replace([np.inf], np.nan)
pmi = pmi.fillna(1)

# %%
#nb.normalize_corpus_dataframe(pmi)

# %% [markdown]
# # Sammenligner med en referanse

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_eacb2748_253e_11ea_959c_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row1_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row1_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row1_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row2_col0 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row2_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row2_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row2_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row2_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row3_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row3_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row3_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row3_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row3_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row4_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row5_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row5_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row6_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row6_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row6_col3 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row6_col4 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row7_col0 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row7_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row8_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row8_col1 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row8_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row8_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row8_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row9_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row9_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row9_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row9_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row10_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row11_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row11_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eacb2748_253e_11ea_959c_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_eb5eec90_253e_11ea_af42_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row1_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row1_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row1_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row2_col0 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row2_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row2_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row2_col3 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row2_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row3_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row3_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row3_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row3_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row3_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row4_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row5_col0 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row5_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row6_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row6_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row6_col3 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row6_col4 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row7_col0 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row7_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row8_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row8_col1 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row8_col2 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row8_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row8_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row9_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row9_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row9_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row9_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row10_col0 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row11_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row11_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eb5eec90_253e_11ea_af42_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row0_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row0_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row4_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row6_col0 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row6_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row6_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row7_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row8_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row8_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row8_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row9_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row10_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row11_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_ebea01b0_253e_11ea_a7bb_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_ec89d32e_253e_11ea_862d_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row1_col3 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row2_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row2_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row2_col4 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row3_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row3_col3 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row4_col1 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row4_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row4_col3 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row5_col0 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row5_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row5_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row10_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row10_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row10_col4 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row11_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ec89d32e_253e_11ea_862d_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_ed251206_253e_11ea_9a86_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row1_col4 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row4_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row5_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row6_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row7_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row8_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row8_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row8_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row9_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row9_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row10_col1 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row10_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row10_col3 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ed251206_253e_11ea_9a86_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row1_col1 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row1_col2 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row1_col3 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row2_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row2_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row4_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row4_col3 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row5_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row6_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row7_col1 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row7_col3 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row7_col4 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row8_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row8_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row9_col0 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row9_col2 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row9_col3 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row11_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row11_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_edbdb91e_253e_11ea_8e5d_000acd2bfab2row11_col4 {
#             background-color:  #023858;
#             color:  #f

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col, top=9):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(top).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(200),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>Arbeidstaker, Pensjonsrettigheter, Parkinsons, Refsums, Føllings, Betjentaspiranter, Lebers, Daltveit, Egenmelding, Blodpropp, SYKEPENGEORDNINGEN, Demoner, Follings, Helsekortordningen, Mædi, Sykepengene, KONTORASPIRANTER, Spisevegring, Arbeidsloshet, Hjertesykdommer, Legevitenskapen, Leddgikt, Forkjølelse, Sukkersyke, Luftveisinfeksjoner, Basedows, Hjelpetjenesten, Lepra, Datterens, Postelever, Molnar, Ekteskapslovgivningen, Rosselands, Leukemi, Særfradrag, Oddvars, Grannet, Sykdommer, Avløsning, Lungeavd, Weils, Rabies, Fortrinnsberettiget, Epilepsi, Frithjov, Sykepenger, Malaria, ALLMENNUTDANNING, Haugelands, Tobakksrøyking, Modre, Gulsott, Sult, Arbeidsgiver, Alderdom, Kronisk, Kondrasjin, Psoriasis, Bilskjema, Odlands</span>
# ## unknown
# <span style='font-size:1.1em'>utstridt, sykedag, skolekontordamene, pusteevne, pliktmessige, legatstifteren, toppbelast-, søskensjalusi, sykepengeansvar, salgsfunksjonærer, legemsfeil, toppbelastning, folketrygdpoeng, oppgaveplikten, treningsavbrekk, influensaliknende, sommernattsdrøm, forbenn, tjenestefrihet, forsørgelse, sykesestre, ketose, uforhet, premiefritagelse, begra-, krigsfare, uforefradrag, papirhytter, tilsynskvinnene, fenylketonuri, rekreasjonsopphold, arbeidsbelastninger, svigerfars, pensjoneringsforhold, plagel, hjemtransport, behandlingsmulighetene, nervosa, speslell, arbeidsuførhet, sykefravaer, sykestønad, pleierens, kvinnearresten, toppbelastninger, tobakkskaderad, forbonn, fravaer, gravelse, røykevanene, medfelelse, hønselammelse, bortfanf, sirkulasjonsorganene, tidspoenget, sestre, alkomani, reisefravær, slitasjegikt, trygdeforhold, eiers, delta-, anorexia, bereging, lønnsutbetaling, sengeleie, kontantstøtte, dcltakelse, influensalignende, tagelse, nettolønn, pensjonsbeløp, deltakclse, rskilt, remmed, uførefradrag, bort-</span>
# ## adj
# <span style='font-size:1.1em'>revmatisk, uhelbredelig, epidemisk, åtteårige, smittsom, tuberkuløs, multippel, arvelig, kurativ, åndssvakt, snikende, framskreden, legemlig, ondartet</span>
# ## subst
# <span style='font-size:1.1em'>sentralbordene, fraværsdag, blødersykdommen, symptomet, arbeidsgiveravgiftene, barnedødelighet, lungeemfysem, sykmelding, ervervsevne, spedalskhet, lymfeknuter, diabetes, rekonvalesent, kreaturene, egenmelding, karenstiden, uførhet, barselpenger, prestasjonslønn, bistillinger, overanstrengelse, nedkomst, særfradraget, alkoholismen, sklerose, lepra, særfradrag, lyte, sykepengene, karensdager, koppergruver, psoriasis, yrkesskade, bortgang, misdannelse, inkubasjonstid, klassefradrag, alderdom, analfabetisme, vanhelse</span>
# ## verb
# <span style='font-size:1.1em'>forbigåes, innberettes, stred, forbigås, kontaktes, herjes, henføres, førtidspensjonert, ferier</span>

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='': pmi.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
freqbarchart = lambda w, title='': agg.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
gchart = lambda w, title='': reference.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord');

# %%
barchart(['skade',
'lidelse','feilernæring'], 'Utvalgte ord');

# %%
freqbarchart(['skade',
'lidelse','feilernæring'], 'Utvalgte ord');

# %%
gchart(['skade',
'lidelse','feilernæring'], 'Utvalgte ord');

# %%
freqbarchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord');

# %%
gchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord');

# %%
barchart('sunn frisk'.split(), 'Utvalgte ord');

# %%
freqbarchart('sunn frisk'.split(), 'Utvalgte ord');

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2)

# %%
commchart(1)

# %%
commchart(3)

# %%
freqbarchart(['skade',
'lidelse','feilernæring'], 'Utvalgte ord');

# %%
def diff_df(df):
    diff = pd.DataFrame()
    for i in range(1, len(df.columns)):
        diff[df.columns[i]] = df[df.columns[i]]/df[df.columns[i-1]]
    diff = diff.replace([np.inf], np.nan)
    diff = diff.dropna()
    return diff

def growing_df(df):
    diff = pd.DataFrame()
    for i in range(1, len(df.columns)):
        diff[df.columns[i]] = df[df.columns[i]] >= df[df.columns[i-1]]
    diff = diff.replace([np.inf], np.nan)
    diff = diff.dropna()
    return diff

def dropping_df(df):
    diff = pd.DataFrame()
    for i in range(1, len(df.columns)):
        diff[df.columns[i]] = df[df.columns[i]] <= df[df.columns[i-1]]
    diff = diff.replace([np.inf], np.nan)
    diff = diff.dropna()
    return diff

# %%
growing = growing_df(pmi).sum(axis=1)
dropping = dropping_df(pmi).sum(axis=1)

# %%
grow = pmi.loc[growing[growing >= 4].index]
growth_set = grow[(grow[1950] > 10) & (grow[1990] > 10)]

# %%
growth_set.style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row1_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row1_col2 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row1_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row2_col1 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row2_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row2_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row3_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row3_col2 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row3_col3 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row4_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row4_col2 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row4_col3 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row5_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row5_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row5_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row6_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row6_col2 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row6_col3 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row7_col1 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row7_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row7_col3 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row7_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row8_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row8_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row8_col3 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row9_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row9_col2 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row9_col3 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row9_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2level0_row0" class="row_heading level0 row0" >alvorlig</th>
#                         <td id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col0" class="data row0 col0" >14.3935</td>
#                         <td id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col1" class="data row0 col1" >14.6557</td>
#                         <td id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col2" class="data row0 col2" >21.0126</td>
#                         <td id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col3" class="data row0 col3" >25.8192</td>
#                         <td id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2row0_col4" class="data row0 col4" >31.5891</td>
#             </tr>
#             <tr>
#                         <th id="T_c47b7f5e_2551_11ea_87a3_000acd2bfab2level0_row1" class="row_heading level0 row1" >kronisk</th>

# %%
growth_set.transpose().plot(kind='bar', rot=0)

# %%
agg.loc[growth_set.index].transpose().plot(kind='bar', rot=0)

# %%
drop = pmi.loc[dropping[dropping >= 4].index]

# %%
drop_set = drop[(500 > drop[1950]) & (drop[1950] > 40) & (drop[1990] > 1)]

drop_set.transpose().plot(kind='bar',rot=0)
