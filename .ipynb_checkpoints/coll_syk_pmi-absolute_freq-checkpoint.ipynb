# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
reference = pd.read_json('avis_agg_sample_20.json')

# %%
keyword = 'syk'

# %%
filename = 'collocation_' + keyword + ".csv"

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=0.8, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ' ,'.join(i)))
# Out:
# <span style='font-size:1.1em'>ensom ,hjelpeløs ,deprimert ,trøtt ,trist ,gammel ,sliten ,slapp ,liten ,blek ,svak ,skrøpelig ,utstøtt ,nervøs ,trett ,trengte ,fattig ,fortvilet ,elendig ,syk ,stresset ,nedfor ,pleietrengende ,nedbrutt ,lei ,skuffet</span>
# <span style='font-size:1.1em'>syk ,skadet ,måtte ,innlagt</span>
# <span style='font-size:1.1em'>syk ,svak ,gammel ,hjelpeløs</span>
# <span style='font-size:1.1em'>deprimert ,sliten ,nedfor ,syk ,lei</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### gammel-Gammel
# <span style='font-size:1.1em'>gammel, Gammel, ung, ny, grå, Ung, Moderne, etterlater, nedslitt, ærverdig, skrøpelig</span>
# ### sliten-nedfor
# <span style='font-size:1.1em'>sliten, nedfor, deprimert, elendig, trist, slapp, fortvilet, lei, trøtt, stresset, trett, stiv, oppgitt, blek, trøytt, nervøs, Såret, suiten, svett, blakk</span>
# ### syk-døde
# <span style='font-size:1.1em'>syk, døde, nedbrutt, syke, dør, pleietrengende, skuffet, trenger, skadde, sengeliggende, vinduer, vindu, sårede, trengte, smittet, levende, gang-, avmagret, svækket, tverr</span>
# ### ensom-fattig
# <span style='font-size:1.1em'>ensom, fattig, svak, hjelpeløs, bitter, liten, alene, splittet, sårbar, rik, redd, glemt, savner, isolert, utstøtt, rig, lite</span>
# ### skadet-måtte
# <span style='font-size:1.1em'>skadet, måtte, innlagt, påkjørt, drept, sjuk, skadd</span>
# ### frisk-sterk
# <span style='font-size:1.1em'>frisk, sterk, sprek, sunn, fruktig, kjekk, ren, freidig</span>
# ### iskald-kynisk
# <span style='font-size:1.1em'>iskald, kynisk</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
from time import time

collocations = dict()
step = 1

for i in range(1950, 2000):
    print(i)
    t0 = time()
    try:
        collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)
    print((time() - t0)/60, "minutter")
# Out:
# 1950
# 0.8044408202171326 minutter
# 1951
# 0.42161029974619546 minutter
# 1952
# 0.4664357622464498 minutter
# 1953
# 0.5229658166567485 minutter
# 1954
# 0.6426079233487447 minutter
# 1955
# 0.5975029031435649 minutter
# 1956
# 0.5661787231763203 minutter
# 1957
# 0.6341134707132975 minutter
# 1958
# 0.5898786028226216 minutter
# 1959
# 0.6563934485117594 minutter
# 1960
# 0.6211319963137308 minutter
# 1961
# 0.8202598373095195 minutter
# 1962
# 0.8995166579882304 minutter
# 1963
# 0.8154373327891032 minutter
# 1964
# 0.6155085762341818 minutter
# 1965
# 0.5937512596448262 minutter
# 1966
# 0.5471014897028605 minutter
# 1967
# 0.5595757722854614 minutter
# 1968
# 0.5084763646125794 minutter
# 1969
# 0.5119998852411906 minutter
# 1970
# 0.4863414208094279 minutter
# 1971
# 0.48301795721054075 minutter
# 1972
# 0.4435226798057556 minutter
# 1973
# 0.4476930896441142 minutter
# 1974
# 0.46358254353205364 minutter
# 1975
# 0.43649278084437054 minutter
# 1976
# 0.41499075492223103 minutter
# 1977
# 0.42253995736440025 minutter
# 1978
# 0.4499389886856079 minutter
# 1979
# 0.45509047508239747 minutter
# 1980
# 0.45944957733154296 minutter
# 1981
# 0.45310335556666054 minutter
# 1982
# 0.47583038012186685 minutter
# 1983
# 0.5143232385317484 minutter
# 1984
# 0.5291427214940388 minutter
# 1985
# 0.6256053407986959 minutter
# 1986
# 0.6115024129549662 minutter
# 1987
# 0.6114176193873088 minutter
# 1988
# 0.6421613335609436 minutter
# 1989
# 1.1160034577051798 minutter
# 1990
# 1.1784517566363018 minutter
# 1991
# 1.1578296224276226 minutter
# 1992
# 1.2149698376655578 minutter
# 1993
# 1.1376041809717814 minutter
# 1994
# 1.2768165349960328 minutter
# 1995
# 1.108541973431905 minutter
# 1996
# 1.2486416459083558 minutter
# 1997
# 1.3528212984402974 minutter
# 1998
# 1.211877961953481 minutter
# 1999
# 1.12949534257253 minutter

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %%
ref = group_frames(reference)
nb.normalize_corpus_dataframe(ref)
# Out:
# True

# %% [markdown]
# # Opptelling

# %% [markdown]
# # Sammenligner med en referanse

# %%
reference.sort_values(by=reference.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col12 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col14 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col15 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col16 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col17 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col18 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col19 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col20 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col21 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col22 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col23 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col24 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col25 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col26 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col27 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col28 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col29 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col30 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col31 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col32 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col33 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col34 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col35 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col36 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col37 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col38 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col39 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col40 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col41 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col42 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col43 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col44 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col45 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col46 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col47 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col48 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row0_col49 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col4 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col5 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col6 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col7 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col8 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_f85db348_5949_11ea_8e36_a0a4c554f2a3row1_col9 {
#             background-color:  #

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row1_col0 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row1_col1 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row1_col2 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row1_col3 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row1_col4 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row2_col0 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row2_col1 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row2_col2 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row2_col3 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row2_col4 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row3_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row3_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row3_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row3_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row3_col4 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row4_col0 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row4_col1 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row4_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row4_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row4_col4 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row5_col0 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row5_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row5_col2 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row5_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row5_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row6_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row6_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row6_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row7_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row7_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row7_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row7_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row7_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row8_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row8_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row8_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row9_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row9_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row9_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }</style><table id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col0" class="data row0 col0" >0.0627433</td>
#                         <td id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col1" class="data row0 col1" >0.0591087</td>
#                         <td id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col2" class="data row0 col2" >0.057845</td>
#                         <td id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col3" class="data row0 col3" >0.0598116</td>
#                         <td id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3row0_col4" class="data row0 col4" >0.0608463</td>
#             </tr>
#             <tr>
#                         <th id="T_f874cb4a_5949_11ea_9874_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >,</th>

# %%
pmi = pd.DataFrame()
exp = 1.02
for i in agg:
    pmi[i] = agg[i]**exp/(pd.concat([agg[i], ref[i]],axis=1).sum(axis=1))

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row1_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row1_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row1_col2 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row1_col3 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row1_col4 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row2_col0 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row2_col1 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row2_col2 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row2_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row2_col4 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row3_col0 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row3_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row3_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row3_col3 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row3_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row4_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row4_col1 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row4_col2 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row4_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row4_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row5_col0 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row5_col1 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row5_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row5_col3 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row5_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row6_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row6_col1 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row6_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row6_col3 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row6_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row7_col0 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row7_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row7_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row7_col4 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row8_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row8_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row8_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row8_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row8_col4 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row9_col0 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row9_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row9_col2 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row9_col3 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row9_col4 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row10_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row10_col1 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row10_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row10_col4 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row11_col0 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row11_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row11_col2 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row11_col3 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_35c34ae8_594b_11ea_8b5a_a0a4c554f2a3row11_col4 {
#             background-color:  #b4c4df;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row1_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row1_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row1_col2 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row1_col3 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row1_col4 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row2_col0 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row2_col1 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row2_col2 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row2_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row2_col4 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row3_col0 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row3_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row3_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row3_col3 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row3_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row4_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row4_col1 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row4_col2 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row4_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row4_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row5_col0 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row5_col1 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row5_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row5_col3 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row5_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row6_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row6_col1 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row6_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row6_col3 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row6_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row7_col0 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row7_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row7_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row7_col4 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row8_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row8_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row8_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row8_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row8_col4 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row9_col0 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row9_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row9_col2 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row9_col3 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row9_col4 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row10_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row10_col1 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row10_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row10_col4 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row11_col0 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row11_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row11_col2 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row11_col3 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_3a100792_594b_11ea_af3c_a0a4c554f2a3row11_col4 {
#             background-color:  #b4c4df;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row0_col0 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row0_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row0_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row1_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row1_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row1_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row2_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row2_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row2_col3 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row3_col0 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row3_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row3_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row4_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row4_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row4_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row5_col0 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row5_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row5_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row6_col0 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row6_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row6_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row7_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row7_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row7_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row8_col0 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row8_col1 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row8_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row9_col0 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row9_col1 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row9_col3 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row10_col0 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row10_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row10_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row11_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row11_col1 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row11_col3 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_3b1ea0be_594b_11ea_8792_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row0_col0 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row0_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row0_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row1_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row1_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row1_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row2_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row2_col3 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row2_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row3_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row3_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row3_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row4_col0 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row4_col1 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row4_col3 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row5_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row5_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row5_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row6_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row6_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row6_col3 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row7_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row7_col3 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row7_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row8_col1 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row9_col0 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row9_col1 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row9_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row10_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row10_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row10_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row11_col0 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row11_col1 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row11_col3 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_3c79e764_594b_11ea_a3a3_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3d355888_594b_11ea_9811_a0a4c554f2a3row0_col0 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row0_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row0_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row1_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row1_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row1_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row3_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row3_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row3_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row4_col0 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row4_col1 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row4_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row5_col4 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row6_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row6_col1 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row6_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row7_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row7_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row7_col3 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row8_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row8_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row8_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row9_col0 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row9_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row9_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row10_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row10_col4 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row11_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row11_col1 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row11_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3d355888_594b_11ea_9811_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(45).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row0_col0 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row0_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row0_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row1_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row1_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row1_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row2_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row2_col1 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row2_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row3_col0 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row3_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row3_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row4_col0 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row4_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row4_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row5_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row5_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row5_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row6_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row6_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row6_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row7_col0 {
#             background-color:  #71a8ce;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row7_col1 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row7_col3 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row8_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row8_col1 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row8_col3 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row9_col0 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row9_col1 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row9_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row10_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row10_col1 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row10_col3 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row11_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row11_col1 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row11_col3 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_3e2d568c_594b_11ea_b31e_a0a4c554f2a3row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(45).fillna(0).index
# Out:
# Index(['alvorlig', 'syk', 'frisk', 'ufør', 'uhelbredelig', 'feber', 'akutt',
#        'kronisk', 'sengeliggende', 'influensa', 'innlagt', 'pasient',
#        'mentalt', 'Syk', 'sykere', 'legen', 'steppe', 'SYK', 'diagnosen',
#        'lungebetennelse', 'sykepenger', 'sykdommen', 'psykisk', 'nedbrutt',
#        'moren', 'plutselig', 'Gjensidige-kontor', 'kreft', 'dø', 'Honecker',
#        'hun', 'Diagnosen', 'Ingemar', 'livstruende', 'kelen', 'uforutsett',
#        'sykdom', 'Politibil', 'pasienten', 'Jeltsin', 'kledde', 'arbeidsufør',
#        'Sykdommen', 'Regnbuebyen', 'Farim'],
#       dtype='object')

# %%
ordliste = ['alvorlig', 'syk', 'frisk', 'ufør', 'uhelbredelig', 'feber', 'akutt',
       'kronisk', 'sengeliggende', 'influensa', 'innlagt', 'pasient',
       'mentalt', 'Syk', 'sykere', 'legen', 'steppe', 'SYK', 'diagnosen',
       'lungebetennelse', 'sykepenger', 'sykdommen', 'psykisk', 'nedbrutt',
       'moren', 'plutselig', 'Gjensidige-kontor', 'kreft', 'dø', 'Honecker',
       'hun', 'Diagnosen', 'Ingemar', 'livstruende', 'kelen', 'uforutsett',
       'sykdom', 'Politibil', 'pasienten', 'Jeltsin', 'kledde', 'arbeidsufør',
       'Sykdommen', 'Regnbuebyen', 'Farim']

# %% [markdown]
# <br>
# <br>

# %%
(agg.loc[ordliste]/ref.loc[ordliste]).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row0_col1 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row0_col2 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row0_col3 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row1_col1 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row1_col2 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row1_col3 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row2_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row2_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row2_col3 {
#             background-color:  #2987bc;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row3_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row3_col3 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row3_col4 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row4_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row4_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row4_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row5_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row5_col3 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row5_col4 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row6_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row6_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row6_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row7_col0 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row7_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row7_col3 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row7_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row8_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row8_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row8_col3 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row8_col4 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row9_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row9_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row9_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row9_col4 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row10_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row10_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row10_col2 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row11_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row11_col2 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_a46f8b62_5955_11ea_ac9c_a0a4c554f2a3row11_col4 {
#             background-color:  #3b92c1;
#             color:  #0

# %%
pmi.to_csv(filename)

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>Musti, Dagros, Boumedienne, Pasienten, Ulbricht, Belgisk, Husmorvikarene, Peron, Begin, Hess, Amin, Stensen, Sigleif, Bolle, Kissinger, Sykdommen, Barne-tv, Myrmæl, Bjørang, Lahti, Haukel, Arbeidsgiveren, Sarah, Tse-tung, Sagstuen, Emmas, Isjkov, Kansas, Teng, Mislimov, Algeries, Karpov, Svendsberget, Kortsjnoj, Spasskij, Houari, Tiberius, Overgangsregel, Adeline, Edelstam, Alberte</span>
# ## unknown
# <span style='font-size:1.1em'>lunsj-pauser, folte, tremila, stemmeberettige, bilutgifter, stemmeberettig-, tegnefilmserie</span>
# ## adj
# <span style='font-size:1.1em'>ufør, uhelbredelig, nedfor, arbeidsufør, døende, sykt, gravid, fredfulle, fraværende, håpløst, stemmeberettigede</span>
# ## subst
# <span style='font-size:1.1em'>kreft, legehjelp, sjahen, magen, kvalm, hjernehinnebetennelse, forkjølelse, konen, senga, alkoholiker, sykepengene, trygdekontoret, arbeidstakeren, katten, alkoholikeren, symptomene, distriktslege, blindtarmen, fiskeriminister, sykemelding, telegrafisten, hjemlengsel, generalen, budet, nyhetsbyrået, dyrlegen</span>
# ## verb
# <span style='font-size:1.1em'>nedbrutt, innlegges, deprimert, lengtet, kledde, avkreftet, tilkalle, innbilt, kua, slør, sykmeldt, versert, hint, budsendt, forkjølet</span>

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
