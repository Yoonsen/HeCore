# %% [markdown]
# # Kollokasjoner for nøkkelord

# %% [markdown]
# 3. Vise og kommentere kollokasjonclusteret til begrepet helse. Kollokasjoner for “environment”, “social”, “life”, “body”, “security”, “risk”, and “care”, “services”, “education”, “sport”, “nutrition”, “children”, and “adolescence”.

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
reference = pd.read_json('avis_agg_sample_20.json')

# %%
keyword = 'miljø'

# %% [markdown]
# ## Grafstruktur topos

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=0.8, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ' ,'.join(i)))
# Out:
# <span style='font-size:1.1em'>aktivitet ,helse ,økonomi ,kunst ,Natur ,kommunalteknikk ,forvaltning ,industri ,skole ,sikkerhet ,teknikk ,velferd ,livskvalitet ,drift ,samferdsel ,næring ,næringsliv ,utvikling ,idrett ,energi ,læring ,Kultur ,kultur ,Menneske ,vekst ,byutvikling ,miljo ,dyr ,trivsel ,næringsutvikling ,velvære ,skog ,landbruk ,plan ,miljø- ,landskap ,miljø ,klima ,samfunn ,natur</span>
# <span style='font-size:1.1em'>helse ,samferdsel ,landbruk ,næring ,kultur ,kommunalteknikk ,byutvikling ,miljø ,utvikling ,natur</span>
# <span style='font-size:1.1em'>byutvikling ,miljø ,samferdsel ,næring ,kultur</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### teknikk-utvikling
# <span style='font-size:1.1em'>teknikk, utvikling, vekst, læring, drift, forvaltning, vitenskap, videnskap, vedlikehold, naturvitenskap, kondisjon, omstilling, taktikk, hurtighet, forsking, forskning</span>
# ### solidaritet-vennskap
# <span style='font-size:1.1em'>solidaritet, vennskap, medmenneskelighet, nestekjærlighet, likeverd, menneskeverd, støtte, samhold, rettferdighet, toleranse, fellesskap</span>
# ### trivsel-helse
# <span style='font-size:1.1em'>trivsel, helse, trygghet, velferd, velvære, skole, omsorg, mat, aktivitet, glede, effektivitet, livskvalitet, fremgang, hygge</span>
# ### sikkerhet-samarbeid
# <span style='font-size:1.1em'>sikkerhet, samarbeid, komfort, kvalitet, beredskap, arbeidsmiljø, stabilitet</span>
# ### landbruk-industri
# <span style='font-size:1.1em'>landbruk, industri, naturbruk, havbruk, skogbruk, fiske, fiskeri, ernæring</span>
# ### miljø-klima
# <span style='font-size:1.1em'>miljø, klima, energi, arv, miljo, biovitenskap, Menneske, miljø-, fiskehelse, sikkerhetsarbeid, pågangsmot, Trafikksikring, gåver, topografi, dyktighet, gaver, Trafikksikkerhet, miljo-, miljøkomiteen, jordsmonn, akvakultur, arveavgift, Vise, entusiasme, Miljø</span>
# ### natur-kommunalteknikk
# <span style='font-size:1.1em'>natur, kommunalteknikk, landskap, skog, plan, miljøvern, Miljø-, friluftsliv, menneske, mennesker, dyr</span>
# ### kultur-samfunn
# <span style='font-size:1.1em'>kultur, samfunn, idrett, næringsliv, Natur, politikk, tradisjon, enkeltmennesker, kunst, individ, arbeidsliv, Teknologi, religion, historie, oppvekst</span>
# ### næring-samferdsel
# <span style='font-size:1.1em'>næring, samferdsel, byutvikling, reiseliv, næringsutvikling, bolig, service, økonomi, transport, Kultur, arkitektur, infrastruktur</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
collocations = dict()
step = 1
for i in range(1950, 2000):
    try:
        collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation(keyword, yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %% [markdown]
# # Opptelling

# %%
reference.sort_values(by=reference.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col12 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col13 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col14 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col15 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col16 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col17 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col18 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col19 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col20 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col21 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col22 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col23 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col24 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col25 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col26 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col27 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col28 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col29 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col30 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col31 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col32 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col33 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col34 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col35 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col36 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col37 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col38 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col39 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col40 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col41 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col42 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col43 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col44 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col45 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col46 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col47 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col48 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row0_col49 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col0 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col3 {
#             background-color:  #3d93c2;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col4 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col5 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col6 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col7 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col8 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0374726e_16dd_11ea_bc1f_a0a4c554f2a3row1_col9 {
#             background-color:  #

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row1_col0 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row1_col1 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row1_col2 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row1_col3 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row1_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row2_col0 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row2_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row2_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row2_col3 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row2_col4 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row3_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row3_col1 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row3_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row3_col3 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row3_col4 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row4_col0 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row4_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row4_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row4_col3 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row4_col4 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row5_col0 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row5_col1 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row5_col2 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row5_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row6_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row6_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row6_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row6_col3 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row6_col4 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row7_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row7_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row7_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row7_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row8_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row8_col3 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row8_col4 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row9_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row9_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row9_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }</style><table id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col0" class="data row0 col0" >0.0509732</td>
#                         <td id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col1" class="data row0 col1" >0.0600621</td>
#                         <td id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col2" class="data row0 col2" >0.0612432</td>
#                         <td id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col3" class="data row0 col3" >0.0611871</td>
#                         <td id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3row0_col4" class="data row0 col4" >0.0589431</td>
#             </tr>
#             <tr>
#                         <th id="T_04095486_16dd_11ea_b4ba_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >og</th>

# %%
pmi = pd.DataFrame()
for i in agg:
    pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-112-6dc4ee76a8f8> in <module>
#       1 pmi = pd.DataFrame()
#       2 for i in agg:
# ----> 3     pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     401
#     402                 index, columns = self.new_axes
# --> 403                 df = cons(data, index=index)
#     404                 df.columns = columns
#     405                 return df.__finalize__(self, method='concat')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      54
#      55     # don't force copy because getting jammed in an ndarray anyway
# ---> 56     arrays = _homogenize(arrays, index, dtype)
#      57
#      58     # from BlockManager perspective
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     263                 # Forces alignment. No need to copy data since we
#     264                 # are putting it into an ndarray later
# --> 265                 val = val.reindex(index, copy=False)
#     266         else:
#     267             if isinstance(val, dict):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3736     @Appender(generic.NDFrame.reindex.__doc__)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#    3740     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4372             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    4373                                              fill_value=fill_value,
# -> 4374                                              copy=copy, allow_dups=False)
#    4375
#    4376         return obj
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1229         if axis == 0:
#    1230             new_blocks = self._slice_take_blocks_ax0(indexer,
# -> 1231                                                      fill_tuple=(fill_value,))
#    1232         else:
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1268                 return [blk.take_nd(slobj, axis=0,
#    1269                                     new_mgr_locs=slice(0, sllen),
# -> 1270                                     fill_tuple=fill_tuple)]
#    1271
#    1272         if sl_type in ('slice', 'mask'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1236             fill_value = fill_tuple[0]
#    1237             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1238                                        allow_fill=True, fill_value=fill_value)
#    1239
#    1240         if new_mgr_locs is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1647             # (s.t. df.values is c-contiguous and df._data.blocks[0] is its
#    1648             # f-contiguous transpose)
# -> 1649             out = np.empty(out_shape, dtype=dtype, order='F')
#    1650         else:
#    1651             out = np.empty(out_shape, dtype=dtype)
#
# MemoryError:

# %%
nb.normalize_corpus_dataframe(pmi)

# %% [markdown]
# # Sammenligner med en referanse

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden 1965-1980 sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='', df=pmi: df.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, frekvens', df=agg);

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord, assosiasjon');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', pmi);

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord', agg);

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
