# %% [markdown]
# # Kollokasjoner for nøkkelord

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
mu.code_toggle()
# Out:
# <div>
#                 <style>
#                  .mybutton {
#                     background-color: lightgrey;
#                     border: none;
#                     color: white;
#                     padding: 10px 16px;
#                     text-align: center;
#                     text-decoration: none;
#                     display: inline-block;
#                     font-size: 16px;
#                     margin: 4px 2px;
#                     cursor: pointer;
#                 }
#             </style>
#             <script>
#                 code_show=true;
#                 function code_toggle() {
#                  if (code_show){
#                  $('div.input').hide();
#                  } else {
#                  $('div.input').show();
#                  }
#                  code_show = !code_show
#                 }
#                 $( document ).ready(code_toggle);
#             </script>
#             <form  action="javascript:code_toggle()">
#                 <input class='mybutton' type="submit" value="Klikk for å vise/skjule kodeceller">
#             </form>
#         </div>

# %%
def categorize(list_of_words):
    proprium = [x for x in list_of_words if x[0].upper() == x[0]]
    other = [x for x in list_of_words if not x in proprium]

    return {'propr':proprium,
           'other': other }

def select_form(w):
    fs = [x.split()[0] for x in nb.word_form(w)]
    if 'verb' in fs:
        res = 'verb'
    elif 'subst' in fs:
        res = 'subst'
    elif len(fs) > 0:
        res = fs[0]
    else:
        res = 'unknown'
    return res

def sort_word_forms(words):
    res = {select_form(w):w for w in words}
    return res

def character_words(Character_name, number_of_words=50):
    res = {w:select_form(w) for w in categorize(list(nb.frame_sort(nb.frame(coll_matrix[Character_name]/tot['tot'], 'association')).head(number_of_words).index))['other']}
    result = {cat:[w for w in res if res[w] == cat] for cat in res.values()}
    return result

def mdprint(forskjell, cutoff=5):
    categories = categorize(forskjell[forskjell > cutoff].dropna().index)
    forms = {w:select_form(w) for w in categories['other']}
    Grouping = {cat:[word for word in forms if forms[word] == cat] for cat in forms.values()}
    navn = "## Benevnelser \n"
    navn += "<span style='font-size:150%'>{stuff}</span>".format(stuff= ', '.join(categories['propr']))
    pos = ""
    for cat in Grouping:
        pos += "## " + cat + "\n"
        pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(Grouping[cat]) ) + "\n"
    mu.printmd(navn)
    mu.printmd(pos)
    return

# %%
import pandas as pd

# %%
import ast

# %%
#colls_before = pd.read_json('demokrati_before.json')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %%
cliques = lambda G: [list(x) for  x in list(gnl.make_cliques_from_graph(G.to_undirected())[1].values())]

# %% [markdown]
# ## Definer nøkkelordet
#
# noteboken blir kjørt flere ganger, en notebook for hvert nøkkelord, *influensa*, *helse*

# %%
keyword = 'influensa'

# %%
keyword_graph = nb.make_graph(keyword, cutoff=16)

# %%
comm = gnl.community_dict(keyword_graph)

# %%
gnl.show_graph(keyword_graph, spread=0.8, fontsize=11)

# %%
keyword_cliques = cliques(keyword_graph)

# %% [markdown]
# # Grafens klikkstruktur (klikk = clique)
#
# Klikkstrukturen er fin for å se overlapp og forskjellige kontekster hvor nøkkelordet forekommer.

# %%
for i in keyword_cliques:
    mu.printmd("<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(i)))
# Out:
# <span style='font-size:1.1em'>feber, hals, hodepine, forkjølelse, influensa, bihulebetennelse, lungebetennelse, bronkitt, forkjølelser, hoste, omgangssyke, Smerter, diaré, Forkjølelse, meslinger, forkjolelse</span>
# <span style='font-size:1.1em'>influensa, tuberkulose, kopper</span>
# <span style='font-size:1.1em'>influensa, svineinfluensa, fugleinfluensa</span>

# %% [markdown]
# # Topoi fra grafen
#
# Der klikkstrukturen kombinerer færre element, er alle nodene i grafen med og definerer et topos.

# %%
pos=""
for x in comm:
    pos += "### " + x + "\n"
    pos += "<span style='font-size:1.1em'>{stuff}</span>".format(stuff= ', '.join(comm[x]) ) + "\n"
mu.printmd(pos)
# Out:
# ### kopper-skåler
# <span style='font-size:1.1em'>kopper, skåler, tallerkener, glass, tallerkner, sink, fat, asjetter</span>
# ### tuberkulose-meslinger
# <span style='font-size:1.1em'>tuberkulose, meslinger, diaré, malaria, polio, hiv, kreft, aids, andre, tyfus, AIDS</span>
# ### influensa-feber
# <span style='font-size:1.1em'>influensa, feber, forkjølelse, hodepine, hoste, forkjolelse, hals, halsbetennelse, kikhoste, halsonde, omgangssyke, influensa-symptomer, oppkast, bihulebetennelse, smerter, tvinger, barnesykdommer</span>
# ### vaksine-medisiner
# <span style='font-size:1.1em'>vaksine, medisiner, attest, stamtavle, ormekur, vet.attest, helseattest, chip</span>
# ### svineinfluensa-finanskrise
# <span style='font-size:1.1em'>svineinfluensa, finanskrise, fugleinfluensa, sesonginfluensa</span>
# ### lungebetennelse-bronkitt
# <span style='font-size:1.1em'>lungebetennelse, bronkitt, forkjølelser, hjernehinnebetennelse, døde, astma</span>
# ### sterk-modig
# <span style='font-size:1.1em'>sterk, modig, rask, smidig, sunn, sund</span>
# ### Forkjølelse-Reumatisme
# <span style='font-size:1.1em'>Forkjølelse, Reumatisme, Smerter</span>

# %% [markdown]
# # Assosiasjoner fra kollokasjonene
#
# <span style="font-size:150%">nb.collocation(keyword, yearfrom=1950, yearto=2000, before=10, after=10, corpus='avis')</span>

# %% [markdown]
# Her ser vi først på referansekorpuset, og validerer det. Det er gruppert på tiår.

# %%
reference = pd.read_json('avis_agg.json')

# %%
barchart = lambda word, df: df.loc[word].plot(kind='bar', rot=0, figsize=(10,5),title=word);

# %%
barchart(keyword, reference);

# %%
collocations = dict()
step = 1
for i in range(1950, 2000):
    try:
        collocations[i] = nb.collocation('influensa', yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
    except:
        try:
            collocations[i] = nb.collocation('influensa', yearfrom=i, yearto=i+step, before = 10, after = 10, corpus = 'avis')
        except:
            print("gir opp", i)

# %%
colls = nb.frame(collocations)

# %%
colls = pd.concat([nb.frame(collocations[i], i) for i in collocations], axis=1).fillna(0)

# %%
def group_frames(df, bins=10, mode='rel'):
    agg = pd.DataFrame()
    step = 10
    for i in range(0, len(df.columns), step):
        agg[df.columns[i]] = df[df.columns[i:i+step]].sum(axis=1)
    return agg

# %%
agg = group_frames(colls)

# %%
nb.normalize_corpus_dataframe(agg)
# Out:
# True

# %% [markdown]
# # Opptelling

# %%
reference.sort_values(by=reference.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row1_col0 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row1_col1 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row1_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row1_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row1_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row2_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row2_col1 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row2_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row2_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row2_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row3_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row3_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row3_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row3_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row3_col4 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row4_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row4_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row4_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row4_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row4_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row5_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row5_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row5_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row5_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row6_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row6_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row6_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row7_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row7_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row7_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row7_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row8_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row8_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row9_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row9_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50b089cc_06f9_11ea_8740_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_50b089cc_06f9_11ea_8740_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50b089cc_06f9_11ea_8740_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col0" class="data row0 col0" >0.0678003</td>
#                         <td id="T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col1" class="data row0 col1" >0.0636145</td>
#                         <td id="T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col2" class="data row0 col2" >0.0626906</td>
#                         <td id="T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col3" class="data row0 col3" >0.0639755</td>
#                         <td id="T_50b089cc_06f9_11ea_8740_000acd2bfab2row0_col4" class="data row0 col4" >0.0677927</td>
#             </tr>
#             <tr>
#                         <th id="T_50b089cc_06f9_11ea_8740_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %%
agg.sort_values(by=agg.columns[2], ascending=False)[:10].style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row1_col2 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row1_col3 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row1_col4 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row2_col0 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row2_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row2_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row2_col3 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row2_col4 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row3_col0 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row3_col1 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row3_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row3_col3 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row3_col4 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row4_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row4_col1 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row4_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row4_col3 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row4_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row5_col0 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row5_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row5_col2 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row5_col3 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row5_col4 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row6_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row6_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row6_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row6_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row6_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row7_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row7_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row8_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row8_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row8_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row8_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row8_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row9_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row9_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row9_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_50bedf9c_06f9_11ea_9224_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1950</th>        <th class="col_heading level0 col1" >1960</th>        <th class="col_heading level0 col2" >1970</th>        <th class="col_heading level0 col3" >1980</th>        <th class="col_heading level0 col4" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2level0_row0" class="row_heading level0 row0" >.</th>
#                         <td id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col0" class="data row0 col0" >0.04891</td>
#                         <td id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col1" class="data row0 col1" >0.0462492</td>
#                         <td id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col2" class="data row0 col2" >0.0534565</td>
#                         <td id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col3" class="data row0 col3" >0.0595072</td>
#                         <td id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2row0_col4" class="data row0 col4" >0.0599577</td>
#             </tr>
#             <tr>
#                         <th id="T_50bedf9c_06f9_11ea_9224_000acd2bfab2level0_row1" class="row_heading level0 row1" >,</th>

# %%
pmi = pd.DataFrame()
for i in agg:
    pmi[i] = agg[i]**1.02/(pd.concat([agg[i], reference[i]],axis=1).sum(axis=1))

# %%
nb.normalize_corpus_dataframe(pmi)
# Out:
# True

# %% [markdown]
# # Sammenligner med en referanse

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # De 15 beste for passende kolonne

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_85875efa_06f9_11ea_9b25_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row0_col1 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row0_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row0_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row0_col4 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row1_col0 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row1_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row1_col2 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row1_col3 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row1_col4 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row2_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row2_col1 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row2_col2 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row2_col3 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row2_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row3_col0 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row3_col1 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row3_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row3_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row3_col4 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row4_col0 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row4_col1 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row4_col2 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row4_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row4_col4 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row5_col0 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row5_col1 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row5_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row5_col3 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row5_col4 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row6_col0 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row6_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row7_col0 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row7_col4 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row8_col0 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row8_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row8_col2 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row8_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row8_col4 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row9_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row9_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row9_col2 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row9_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row9_col4 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row10_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row10_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row10_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row10_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row10_col4 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row11_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row11_col1 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row11_col2 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row11_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_85875efa_06f9_11ea_9b25_000acd2bfab2row11_col4 {
#             background-color:  #04588a;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(15).fillna(0).style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row0_col1 {
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row0_col2 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row0_col3 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row0_col4 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row1_col0 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row1_col1 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row1_col2 {
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row1_col3 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row1_col4 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row2_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row2_col1 {
#             background-color:  #03446a;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row2_col2 {
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row2_col3 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row2_col4 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row3_col0 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row3_col1 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row3_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row3_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row3_col4 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row4_col0 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row4_col1 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row4_col2 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row4_col3 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row4_col4 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row5_col0 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row5_col1 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row5_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row5_col3 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row5_col4 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row6_col0 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row6_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row6_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row7_col0 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row7_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row7_col4 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row8_col0 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row8_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row8_col2 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row8_col3 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row8_col4 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row9_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row9_col1 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row9_col2 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row9_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row9_col4 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row10_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row10_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row10_col2 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row10_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row10_col4 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row11_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row11_col1 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row11_col2 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row11_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_8652a78a_06f9_11ea_9b0f_000acd2bfab2row11_col4 {
#             background-color:  #04588a;
#             color:  #f

# %%
pmi.sort_values(by=pmi.columns[1], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_871433d8_06f9_11ea_8215_000acd2bfab2row0_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row0_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row0_col3 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row1_col0 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row1_col1 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row1_col3 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row2_col0 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row2_col1 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row2_col3 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row3_col0 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row3_col1 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row3_col3 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row4_col0 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row4_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row4_col3 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row5_col0 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row5_col1 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row5_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row6_col0 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row6_col1 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row6_col3 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row7_col0 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row7_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row7_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row8_col0 {
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row8_col1 {
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row8_col3 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row9_col0 {
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row9_col1 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row9_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row10_col0 {
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row10_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row10_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row11_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row11_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row11_col3 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_871433d8_06f9_11ea_8215_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[2], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row0_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row0_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row0_col3 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row1_col0 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row1_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row1_col3 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row2_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row2_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row2_col3 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row3_col0 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row3_col1 {
#             background-color:  #2182b9;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row3_col3 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row4_col0 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row4_col1 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row4_col3 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row5_col0 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row5_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row5_col3 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row5_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row6_col0 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row6_col1 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row6_col3 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row7_col0 {
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row7_col1 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row7_col3 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row8_col0 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row8_col1 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row8_col3 {
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row9_col0 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row9_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row9_col3 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row9_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row10_col1 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row10_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row11_col0 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row11_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row11_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_87cd089e_06f9_11ea_a0d0_000acd2bfab2row11_col4 {
#             background-color:  #fff7fb;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[3], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_887b5798_06f9_11ea_aada_000acd2bfab2row0_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row0_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row0_col3 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row1_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row1_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row1_col3 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row2_col4 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row3_col0 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row3_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row3_col3 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row4_col0 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row4_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row4_col3 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row5_col1 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row5_col2 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row5_col4 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row6_col0 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row6_col1 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row6_col3 {
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row7_col0 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row7_col1 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row7_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row7_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row7_col4 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row8_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row8_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row9_col0 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row9_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row9_col2 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row9_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row9_col4 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row10_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row10_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row11_col1 {
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row11_col3 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_887b5798_06f9_11ea_aada_000acd2bfab2row11_col4 {
#             background-color:  #6ba5cd;
#             color:  #0

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(15).fillna(0).style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row0_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row0_col1 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row0_col3 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row1_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row1_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row1_col3 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row2_col4 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row3_col0 {
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row3_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row3_col3 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row4_col0 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row4_col1 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row4_col3 {
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row5_col0 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row5_col2 {
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row5_col4 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row6_col0 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row6_col1 {
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row6_col3 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row7_col0 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row7_col1 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row7_col3 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row8_col0 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row8_col1 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row8_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row8_col3 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row9_col1 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row9_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row9_col3 {
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row9_col4 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row10_col0 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row10_col1 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row10_col3 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row10_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row11_col2 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row11_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_89384a70_06f9_11ea_9e4a_000acd2bfab2row11_col4 {
#             background-color:  #569dc8;
#             color:  #0

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Assosiasjoner og variasjon over år.

# %%
pmi.sort_values(by=pmi.columns[0], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
def freq_assoc_val(agg, pmi, col):
    vals = list(pmi.sort_values(by=pmi.columns[col], ascending=False).head(5).fillna(0).index)
    agg.loc[vals].sort_values(by= agg.columns[col], ascending=False).transpose().plot(kind="bar", rot=0, figsize=(12, 8))

# %%
freq_assoc_val(agg, pmi, 0)

# %%
freq_assoc_val(agg, pmi, 1)

# %%
freq_assoc_val(agg, pmi, 3)

# %%
freq_assoc_val(agg, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 1)

# %%
freq_assoc_val(pmi, pmi, 2)

# %%
freq_assoc_val(pmi, pmi, 3)

# %%
freq_assoc_val(pmi, pmi, 4)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
freq_assoc_val(pmi, pmi, 0)

# %%
pmi.sort_values(by=pmi.columns[4], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(12, 8));

# %%
agg.sort_values(by=agg.columns[3], ascending=False).head(5).fillna(0).transpose().plot(kind='bar', rot=20, figsize=(14, 8));

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # De hundre ordene med høyest assosiasjon for perioden 1965-1980 sortert på ordklasser

# %%
mdprint(pmi.sort_values(by=pmi.columns[2], ascending=False).head(100),-1)
# Out:
# ## Benevnelser
# <span style='font-size:150%'>DISPRIL, Dispril, Forkjølelse, Influensa, Anti-neuralgica, Übehag, Meslinger, Giktplager, Influensaen, Formiddagstoner, Antineuralgica, Sykdommen, Hodepine, Menstruasjonssmerter, Vaksine</span>
# ## subst
# <span style='font-size:1.1em'>forkjølelse, feber, kusma, lungebetennelse, influensa, skabb, vaksine, symptomer, vannkopper, lindring, akutt, hunder, snev, virus, meslinger, halsesyke, menstruasjonssmerter, muskelsmerter, rode, diaré, hodepine, tilfeller, bamblesyke, sykdommen, gonoré, giktfeber, sengen, rosen, infeksjonssykdommer, kroppen, sykdommer, bronkitt, tannpine, tuberkulose, epidemi, influensaen, vaksinasjon, faren, symptomene, vaksinen</span>
# ## unknown
# <span style='font-size:1.1em'>übehag, sengs, forkjolelse, forkjølelses-, maveirritasjon, luftveisinfeksjoner, menstruasjons-, oppløs-, forkjolelses-, gonore, halsbetennelse, diarré, forkjelelses-, maveirrilasjon, magesyke</span>
# ## verb
# <span style='font-size:1.1em'>smerter, plager, plaget, anbefales, vaksinert, siver, kontaktes, pådratt, rammet, vaksinere, herjer, egnet, forfall, lege, herjet, stoffet, lindrer, kopper, plages, pådro</span>
# ## adj
# <span style='font-size:1.1em'>reumatiske, virksomme, sengeliggende, langvarige, syk, vanligste, indisponert, epidemisk, akutte</span>
# ## fork
# <span style='font-size:1.1em'>f.eks.</span>

# %% [markdown]
# # Hvordan utvikler ordene seg?

# %%
barchart = lambda w, title='': pmi.loc[w].transpose().plot(kind='bar',title=title, rot=20, figsize=(12,6)) ;

# %%
barchart(['helse','kreft',"sengeliggende", 'arbeidsplassen'], 'Utvalgte ord');

# %% [markdown]
# <br>
# <br>
#
# # Sjekk ut vanlige ord
#
# Bare for å se at de har lave verdier og er stabile gjennom kollokasjonen

# %%
barchart(['.','og', ',','eller', 'men'], 'Punktueringer og vanlige ord');

# %% [markdown]
# <br>
# <br>
#
# # De fremste blandt topoi
#
# Merk at på grunn av louvain-algoritmen kan topoiene endre seg litt fra kjøring til kjøring

# %%
commchart = lambda x, part =(1,6): barchart(comm[list(comm.keys())[x]][part[0]:part[1]], list(comm.keys())[x]);

# %%
commchart(2, (0,5));

# %%
commchart(1, (3, 8))

# %%
commchart(3)
